# %%
import gymnasium as gym
import numpy as np
import pygame
import random

# %%
env = gym.make(id="Taxi-v3",render_mode="human")

# %%
def ValueIteration(env,gamma=0.90,epsilon=1e-3,maxEpisodes=1000):
    S = list(range(env.observation_space.n))
    V = {s: 0 for s in S}

    maxDiff = epsilon+0.1
    episode=0
    while maxDiff > epsilon and episode < maxEpisodes:
        for s in S:
            v = -np.inf
            stateChangingActions = env.unwrapped.action_mask(s)
            stateChangingActions = np.where(stateChangingActions)[0]

            tempV = 0
            for a in stateChangingActions:
                _,nextState,reward,_ = env.unwrapped.P[s][a][0]
                tempV = reward + gamma*V[nextState]
                v = max(v,tempV)
            
            maxDiff = max(maxDiff,abs(V[s]-v))
            V[s] = v
        
        episode+=1
        print(f"Completed {episode/maxEpisodes*100} % of episodes")
        print(f"Max difference: {maxDiff}")

    print(f"done")
    return V

# %%
def Policy(env,V,gamma=0.90):
    S = list(range(env.observation_space.n))
    A = list(range(env.action_space.n))
    Policy = {s: random.sample(A,1)[0] for s in S}

    for s in S:
        maxV = -np.inf
        optimalAction = -1

        stateChangingActions = env.unwrapped.action_mask(s)
        stateChangingActions = np.where(stateChangingActions)[0]

        for a in stateChangingActions:
            _,nextState,reward,_ = env.unwrapped.P[s][a][0]
            tempV = 0
            tempV += reward + gamma * V[nextState]
            
            if tempV > maxV:
                maxV = tempV
                optimalAction = a
        
        Policy[s] = optimalAction
    
    return Policy

# %%
V = ValueIteration(env)
Policy = Policy(env,V)
# Out:
# Completed 0.1 % of episodes
# Max difference: 19.1
# Completed 0.2 % of episodes
# Max difference: 19.1
# Completed 0.3 % of episodes
# Max difference: 19.1
# Completed 0.4 % of episodes
# Max difference: 19.1
# Completed 0.5 % of episodes
# Max difference: 19.1
# Completed 0.6 % of episodes
# Max difference: 19.1
# Completed 0.7000000000000001 % of episodes
# Max difference: 19.1
# Completed 0.8 % of episodes
# Max difference: 19.1
# Completed 0.8999999999999999 % of episodes
# Max difference: 19.1
# Completed 1.0 % of episodes
# Max difference: 19.1
# Completed 1.0999999999999999 % of episodes
# Max difference: 19.1
# Completed 1.2 % of episodes
# Max difference: 19.1
# Completed 1.3 % of episodes
# Max difference: 19.1
# Completed 1.4000000000000001 % of episodes
# Max difference: 19.1
# Completed 1.5 % of episodes
# Max difference: 19.1
# Completed 1.6 % of episodes
# Max difference: 19.1
# Completed 1.7000000000000002 % of episodes
# Max difference: 19.1
# Completed 1.7999999999999998 % of episodes
# Max difference: 19.1
# Completed 1.9 % of episodes
# Max difference: 19.1
# Completed 2.0 % of episodes
# Max difference: 19.1
# Completed 2.1 % of episodes
# Max difference: 19.1
# Completed 2.1999999999999997 % of episodes
# Max difference: 19.1
# Completed 2.3 % of episodes
# Max difference: 19.1
# Completed 2.4 % of episodes
# Max difference: 19.1
# Completed 2.5 % of episodes
# Max difference: 19.1
# Completed 2.6 % of episodes
# Max difference: 19.1
# Completed 2.7 % of episodes
# Max difference: 19.1
# Completed 2.8000000000000003 % of episodes
# Max difference: 19.1
# Completed 2.9000000000000004 % of episodes
# Max difference: 19.1
# Completed 3.0 % of episodes
# Max difference: 19.1
# Completed 3.1 % of episodes
# Max difference: 19.1
# Completed 3.2 % of episodes
# Max difference: 19.1
# Completed 3.3000000000000003 % of episodes
# Max difference: 19.1
# Completed 3.4000000000000004 % of episodes
# Max difference: 19.1
# Completed 3.5000000000000004 % of episodes
# Max difference: 19.1
# Completed 3.5999999999999996 % of episodes
# Max difference: 19.1
# Completed 3.6999999999999997 % of episodes
# Max difference: 19.1
# Completed 3.8 % of episodes
# Max difference: 19.1
# Completed 3.9 % of episodes
# Max difference: 19.1
# Completed 4.0 % of episodes
# Max difference: 19.1
# Completed 4.1000000000000005 % of episodes
# Max difference: 19.1
# Completed 4.2 % of episodes
# Max difference: 19.1
# Completed 4.3 % of episodes
# Max difference: 19.1
# Completed 4.3999999999999995 % of episodes
# Max difference: 19.1
# Completed 4.5 % of episodes
# Max difference: 19.1
# Completed 4.6 % of episodes
# Max difference: 19.1
# Completed 4.7 % of episodes
# Max difference: 19.1
# Completed 4.8 % of episodes
# Max difference: 19.1
# Completed 4.9 % of episodes
# Max difference: 19.1
# Completed 5.0 % of episodes
# Max difference: 19.1
# Completed 5.1 % of episodes
# Max difference: 19.1
# Completed 5.2 % of episodes
# Max difference: 19.1
# Completed 5.3 % of episodes
# Max difference: 19.1
# Completed 5.4 % of episodes
# Max difference: 19.1
# Completed 5.5 % of episodes
# Max difference: 19.1
# Completed 5.6000000000000005 % of episodes
# Max difference: 19.1
# Completed 5.7 % of episodes
# Max difference: 19.1
# Completed 5.800000000000001 % of episodes
# Max difference: 19.1
# Completed 5.8999999999999995 % of episodes
# Max difference: 19.1
# Completed 6.0 % of episodes
# Max difference: 19.1
# Completed 6.1 % of episodes
# Max difference: 19.1
# Completed 6.2 % of episodes
# Max difference: 19.1
# Completed 6.3 % of episodes
# Max difference: 19.1
# Completed 6.4 % of episodes
# Max difference: 19.1
# Completed 6.5 % of episodes
# Max difference: 19.1
# Completed 6.6000000000000005 % of episodes
# Max difference: 19.1
# Completed 6.7 % of episodes
# Max difference: 19.1
# Completed 6.800000000000001 % of episodes
# Max difference: 19.1
# Completed 6.9 % of episodes
# Max difference: 19.1
# Completed 7.000000000000001 % of episodes
# Max difference: 19.1
# Completed 7.1 % of episodes
# Max difference: 19.1
# Completed 7.199999999999999 % of episodes
# Max difference: 19.1
# Completed 7.3 % of episodes
# Max difference: 19.1
# Completed 7.3999999999999995 % of episodes
# Max difference: 19.1
# Completed 7.5 % of episodes
# Max difference: 19.1
# Completed 7.6 % of episodes
# Max difference: 19.1
# Completed 7.7 % of episodes
# Max difference: 19.1
# Completed 7.8 % of episodes
# Max difference: 19.1
# Completed 7.9 % of episodes
# Max difference: 19.1
# Completed 8.0 % of episodes
# Max difference: 19.1
# Completed 8.1 % of episodes
# Max difference: 19.1
# Completed 8.200000000000001 % of episodes
# Max difference: 19.1
# Completed 8.3 % of episodes
# Max difference: 19.1
# Completed 8.4 % of episodes
# Max difference: 19.1
# Completed 8.5 % of episodes
# Max difference: 19.1
# Completed 8.6 % of episodes
# Max difference: 19.1
# Completed 8.7 % of episodes
# Max difference: 19.1
# Completed 8.799999999999999 % of episodes
# Max difference: 19.1
# Completed 8.9 % of episodes
# Max difference: 19.1
# Completed 9.0 % of episodes
# Max difference: 19.1
# Completed 9.1 % of episodes
# Max difference: 19.1
# Completed 9.2 % of episodes
# Max difference: 19.1
# Completed 9.3 % of episodes
# Max difference: 19.1
# Completed 9.4 % of episodes
# Max difference: 19.1
# Completed 9.5 % of episodes
# Max difference: 19.1
# Completed 9.6 % of episodes
# Max difference: 19.1
# Completed 9.700000000000001 % of episodes
# Max difference: 19.1
# Completed 9.8 % of episodes
# Max difference: 19.1
# Completed 9.9 % of episodes
# Max difference: 19.1
# Completed 10.0 % of episodes
# Max difference: 19.1
# Completed 10.100000000000001 % of episodes
# Max difference: 19.1
# Completed 10.2 % of episodes
# Max difference: 19.1
# Completed 10.299999999999999 % of episodes
# Max difference: 19.1
# Completed 10.4 % of episodes
# Max difference: 19.1
# Completed 10.5 % of episodes
# Max difference: 19.1
# Completed 10.6 % of episodes
# Max difference: 19.1
# Completed 10.7 % of episodes
# Max difference: 19.1
# Completed 10.8 % of episodes
# Max difference: 19.1
# Completed 10.9 % of episodes
# Max difference: 19.1
# Completed 11.0 % of episodes
# Max difference: 19.1
# Completed 11.1 % of episodes
# Max difference: 19.1
# Completed 11.200000000000001 % of episodes
# Max difference: 19.1
# Completed 11.3 % of episodes
# Max difference: 19.1
# Completed 11.4 % of episodes
# Max difference: 19.1
# Completed 11.5 % of episodes
# Max difference: 19.1
# Completed 11.600000000000001 % of episodes
# Max difference: 19.1
# Completed 11.700000000000001 % of episodes
# Max difference: 19.1
# Completed 11.799999999999999 % of episodes
# Max difference: 19.1
# Completed 11.899999999999999 % of episodes
# Max difference: 19.1
# Completed 12.0 % of episodes
# Max difference: 19.1
# Completed 12.1 % of episodes
# Max difference: 19.1
# Completed 12.2 % of episodes
# Max difference: 19.1
# Completed 12.3 % of episodes
# Max difference: 19.1
# Completed 12.4 % of episodes
# Max difference: 19.1
# Completed 12.5 % of episodes
# Max difference: 19.1
# Completed 12.6 % of episodes
# Max difference: 19.1
# Completed 12.7 % of episodes
# Max difference: 19.1
# Completed 12.8 % of episodes
# Max difference: 19.1
# Completed 12.9 % of episodes
# Max difference: 19.1
# Completed 13.0 % of episodes
# Max difference: 19.1
# Completed 13.100000000000001 % of episodes
# Max difference: 19.1
# Completed 13.200000000000001 % of episodes
# Max difference: 19.1
# Completed 13.3 % of episodes
# Max difference: 19.1
# Completed 13.4 % of episodes
# Max difference: 19.1
# Completed 13.5 % of episodes
# Max difference: 19.1
# Completed 13.600000000000001 % of episodes
# Max difference: 19.1
# Completed 13.700000000000001 % of episodes
# Max difference: 19.1
# Completed 13.8 % of episodes
# Max difference: 19.1
# Completed 13.900000000000002 % of episodes
# Max difference: 19.1
# Completed 14.000000000000002 % of episodes
# Max difference: 19.1
# Completed 14.099999999999998 % of episodes
# Max difference: 19.1
# Completed 14.2 % of episodes
# Max difference: 19.1
# Completed 14.299999999999999 % of episodes
# Max difference: 19.1
# Completed 14.399999999999999 % of episodes
# Max difference: 19.1
# Completed 14.499999999999998 % of episodes
# Max difference: 19.1
# Completed 14.6 % of episodes
# Max difference: 19.1
# Completed 14.7 % of episodes
# Max difference: 19.1
# Completed 14.799999999999999 % of episodes
# Max difference: 19.1
# Completed 14.899999999999999 % of episodes
# Max difference: 19.1
# Completed 15.0 % of episodes
# Max difference: 19.1
# Completed 15.1 % of episodes
# Max difference: 19.1
# Completed 15.2 % of episodes
# Max difference: 19.1
# Completed 15.299999999999999 % of episodes
# Max difference: 19.1
# Completed 15.4 % of episodes
# Max difference: 19.1
# Completed 15.5 % of episodes
# Max difference: 19.1
# Completed 15.6 % of episodes
# Max difference: 19.1
# Completed 15.7 % of episodes
# Max difference: 19.1
# Completed 15.8 % of episodes
# Max difference: 19.1
# Completed 15.9 % of episodes
# Max difference: 19.1
# Completed 16.0 % of episodes
# Max difference: 19.1
# Completed 16.1 % of episodes
# Max difference: 19.1
# Completed 16.2 % of episodes
# Max difference: 19.1
# Completed 16.3 % of episodes
# Max difference: 19.1
# Completed 16.400000000000002 % of episodes
# Max difference: 19.1
# Completed 16.5 % of episodes
# Max difference: 19.1
# Completed 16.6 % of episodes
# Max difference: 19.1
# Completed 16.7 % of episodes
# Max difference: 19.1
# Completed 16.8 % of episodes
# Max difference: 19.1
# Completed 16.900000000000002 % of episodes
# Max difference: 19.1
# Completed 17.0 % of episodes
# Max difference: 19.1
# Completed 17.1 % of episodes
# Max difference: 19.1
# Completed 17.2 % of episodes
# Max difference: 19.1
# Completed 17.299999999999997 % of episodes
# Max difference: 19.1
# Completed 17.4 % of episodes
# Max difference: 19.1
# Completed 17.5 % of episodes
# Max difference: 19.1
# Completed 17.599999999999998 % of episodes
# Max difference: 19.1
# Completed 17.7 % of episodes
# Max difference: 19.1
# Completed 17.8 % of episodes
# Max difference: 19.1
# Completed 17.9 % of episodes
# Max difference: 19.1
# Completed 18.0 % of episodes
# Max difference: 19.1
# Completed 18.099999999999998 % of episodes
# Max difference: 19.1
# Completed 18.2 % of episodes
# Max difference: 19.1
# Completed 18.3 % of episodes
# Max difference: 19.1
# Completed 18.4 % of episodes
# Max difference: 19.1
# Completed 18.5 % of episodes
# Max difference: 19.1
# Completed 18.6 % of episodes
# Max difference: 19.1
# Completed 18.7 % of episodes
# Max difference: 19.1
# Completed 18.8 % of episodes
# Max difference: 19.1
# Completed 18.9 % of episodes
# Max difference: 19.1
# Completed 19.0 % of episodes
# Max difference: 19.1
# Completed 19.1 % of episodes
# Max difference: 19.1
# Completed 19.2 % of episodes
# Max difference: 19.1
# Completed 19.3 % of episodes
# Max difference: 19.1
# Completed 19.400000000000002 % of episodes
# Max difference: 19.1
# Completed 19.5 % of episodes
# Max difference: 19.1
# Completed 19.6 % of episodes
# Max difference: 19.1
# Completed 19.7 % of episodes
# Max difference: 19.1
# Completed 19.8 % of episodes
# Max difference: 19.1
# Completed 19.900000000000002 % of episodes
# Max difference: 19.1
# Completed 20.0 % of episodes
# Max difference: 19.1
# Completed 20.1 % of episodes
# Max difference: 19.1
# Completed 20.200000000000003 % of episodes
# Max difference: 19.1
# Completed 20.3 % of episodes
# Max difference: 19.1
# Completed 20.4 % of episodes
# Max difference: 19.1
# Completed 20.5 % of episodes
# Max difference: 19.1
# Completed 20.599999999999998 % of episodes
# Max difference: 19.1
# Completed 20.7 % of episodes
# Max difference: 19.1
# Completed 20.8 % of episodes
# Max difference: 19.1
# Completed 20.9 % of episodes
# Max difference: 19.1
# Completed 21.0 % of episodes
# Max difference: 19.1
# Completed 21.099999999999998 % of episodes
# Max difference: 19.1
# Completed 21.2 % of episodes
# Max difference: 19.1
# Completed 21.3 % of episodes
# Max difference: 19.1
# Completed 21.4 % of episodes
# Max difference: 19.1
# Completed 21.5 % of episodes
# Max difference: 19.1
# Completed 21.6 % of episodes
# Max difference: 19.1
# Completed 21.7 % of episodes
# Max difference: 19.1
# Completed 21.8 % of episodes
# Max difference: 19.1
# Completed 21.9 % of episodes
# Max difference: 19.1
# Completed 22.0 % of episodes
# Max difference: 19.1
# Completed 22.1 % of episodes
# Max difference: 19.1
# Completed 22.2 % of episodes
# Max difference: 19.1
# Completed 22.3 % of episodes
# Max difference: 19.1
# Completed 22.400000000000002 % of episodes
# Max difference: 19.1
# Completed 22.5 % of episodes
# Max difference: 19.1
# Completed 22.6 % of episodes
# Max difference: 19.1
# Completed 22.7 % of episodes
# Max difference: 19.1
# Completed 22.8 % of episodes
# Max difference: 19.1
# Completed 22.900000000000002 % of episodes
# Max difference: 19.1
# Completed 23.0 % of episodes
# Max difference: 19.1
# Completed 23.1 % of episodes
# Max difference: 19.1
# Completed 23.200000000000003 % of episodes
# Max difference: 19.1
# Completed 23.3 % of episodes
# Max difference: 19.1
# Completed 23.400000000000002 % of episodes
# Max difference: 19.1
# Completed 23.5 % of episodes
# Max difference: 19.1
# Completed 23.599999999999998 % of episodes
# Max difference: 19.1
# Completed 23.7 % of episodes
# Max difference: 19.1
# Completed 23.799999999999997 % of episodes
# Max difference: 19.1
# Completed 23.9 % of episodes
# Max difference: 19.1
# Completed 24.0 % of episodes
# Max difference: 19.1
# Completed 24.099999999999998 % of episodes
# Max difference: 19.1
# Completed 24.2 % of episodes
# Max difference: 19.1
# Completed 24.3 % of episodes
# Max difference: 19.1
# Completed 24.4 % of episodes
# Max difference: 19.1
# Completed 24.5 % of episodes
# Max difference: 19.1
# Completed 24.6 % of episodes
# Max difference: 19.1
# Completed 24.7 % of episodes
# Max difference: 19.1
# Completed 24.8 % of episodes
# Max difference: 19.1
# Completed 24.9 % of episodes
# Max difference: 19.1
# Completed 25.0 % of episodes
# Max difference: 19.1
# Completed 25.1 % of episodes
# Max difference: 19.1
# Completed 25.2 % of episodes
# Max difference: 19.1
# Completed 25.3 % of episodes
# Max difference: 19.1
# Completed 25.4 % of episodes
# Max difference: 19.1
# Completed 25.5 % of episodes
# Max difference: 19.1
# Completed 25.6 % of episodes
# Max difference: 19.1
# Completed 25.7 % of episodes
# Max difference: 19.1
# Completed 25.8 % of episodes
# Max difference: 19.1
# Completed 25.900000000000002 % of episodes
# Max difference: 19.1
# Completed 26.0 % of episodes
# Max difference: 19.1
# Completed 26.1 % of episodes
# Max difference: 19.1
# Completed 26.200000000000003 % of episodes
# Max difference: 19.1
# Completed 26.3 % of episodes
# Max difference: 19.1
# Completed 26.400000000000002 % of episodes
# Max difference: 19.1
# Completed 26.5 % of episodes
# Max difference: 19.1
# Completed 26.6 % of episodes
# Max difference: 19.1
# Completed 26.700000000000003 % of episodes
# Max difference: 19.1
# Completed 26.8 % of episodes
# Max difference: 19.1
# Completed 26.900000000000002 % of episodes
# Max difference: 19.1
# Completed 27.0 % of episodes
# Max difference: 19.1
# Completed 27.1 % of episodes
# Max difference: 19.1
# Completed 27.200000000000003 % of episodes
# Max difference: 19.1
# Completed 27.3 % of episodes
# Max difference: 19.1
# Completed 27.400000000000002 % of episodes
# Max difference: 19.1
# Completed 27.500000000000004 % of episodes
# Max difference: 19.1
# Completed 27.6 % of episodes
# Max difference: 19.1
# Completed 27.700000000000003 % of episodes
# Max difference: 19.1
# Completed 27.800000000000004 % of episodes
# Max difference: 19.1
# Completed 27.900000000000002 % of episodes
# Max difference: 19.1
# Completed 28.000000000000004 % of episodes
# Max difference: 19.1
# Completed 28.1 % of episodes
# Max difference: 19.1
# Completed 28.199999999999996 % of episodes
# Max difference: 19.1
# Completed 28.299999999999997 % of episodes
# Max difference: 19.1
# Completed 28.4 % of episodes
# Max difference: 19.1
# Completed 28.499999999999996 % of episodes
# Max difference: 19.1
# Completed 28.599999999999998 % of episodes
# Max difference: 19.1
# Completed 28.7 % of episodes
# Max difference: 19.1
# Completed 28.799999999999997 % of episodes
# Max difference: 19.1
# Completed 28.9 % of episodes
# Max difference: 19.1
# Completed 28.999999999999996 % of episodes
# Max difference: 19.1
# Completed 29.099999999999998 % of episodes
# Max difference: 19.1
# Completed 29.2 % of episodes
# Max difference: 19.1
# Completed 29.299999999999997 % of episodes
# Max difference: 19.1
# Completed 29.4 % of episodes
# Max difference: 19.1
# Completed 29.5 % of episodes
# Max difference: 19.1
# Completed 29.599999999999998 % of episodes
# Max difference: 19.1
# Completed 29.7 % of episodes
# Max difference: 19.1
# Completed 29.799999999999997 % of episodes
# Max difference: 19.1
# Completed 29.9 % of episodes
# Max difference: 19.1
# Completed 30.0 % of episodes
# Max difference: 19.1
# Completed 30.099999999999998 % of episodes
# Max difference: 19.1
# Completed 30.2 % of episodes
# Max difference: 19.1
# Completed 30.3 % of episodes
# Max difference: 19.1
# Completed 30.4 % of episodes
# Max difference: 19.1
# Completed 30.5 % of episodes
# Max difference: 19.1
# Completed 30.599999999999998 % of episodes
# Max difference: 19.1
# Completed 30.7 % of episodes
# Max difference: 19.1
# Completed 30.8 % of episodes
# Max difference: 19.1
# Completed 30.9 % of episodes
# Max difference: 19.1
# Completed 31.0 % of episodes
# Max difference: 19.1
# Completed 31.1 % of episodes
# Max difference: 19.1
# Completed 31.2 % of episodes
# Max difference: 19.1
# Completed 31.3 % of episodes
# Max difference: 19.1
# Completed 31.4 % of episodes
# Max difference: 19.1
# Completed 31.5 % of episodes
# Max difference: 19.1
# Completed 31.6 % of episodes
# Max difference: 19.1
# Completed 31.7 % of episodes
# Max difference: 19.1
# Completed 31.8 % of episodes
# Max difference: 19.1
# Completed 31.900000000000002 % of episodes
# Max difference: 19.1
# Completed 32.0 % of episodes
# Max difference: 19.1
# Completed 32.1 % of episodes
# Max difference: 19.1
# Completed 32.2 % of episodes
# Max difference: 19.1
# Completed 32.300000000000004 % of episodes
# Max difference: 19.1
# Completed 32.4 % of episodes
# Max difference: 19.1
# Completed 32.5 % of episodes
# Max difference: 19.1
# Completed 32.6 % of episodes
# Max difference: 19.1
# Completed 32.7 % of episodes
# Max difference: 19.1
# Completed 32.800000000000004 % of episodes
# Max difference: 19.1
# Completed 32.9 % of episodes
# Max difference: 19.1
# Completed 33.0 % of episodes
# Max difference: 19.1
# Completed 33.1 % of episodes
# Max difference: 19.1
# Completed 33.2 % of episodes
# Max difference: 19.1
# Completed 33.300000000000004 % of episodes
# Max difference: 19.1
# Completed 33.4 % of episodes
# Max difference: 19.1
# Completed 33.5 % of episodes
# Max difference: 19.1
# Completed 33.6 % of episodes
# Max difference: 19.1
# Completed 33.7 % of episodes
# Max difference: 19.1
# Completed 33.800000000000004 % of episodes
# Max difference: 19.1
# Completed 33.900000000000006 % of episodes
# Max difference: 19.1
# Completed 34.0 % of episodes
# Max difference: 19.1
# Completed 34.1 % of episodes
# Max difference: 19.1
# Completed 34.2 % of episodes
# Max difference: 19.1
# Completed 34.300000000000004 % of episodes
# Max difference: 19.1
# Completed 34.4 % of episodes
# Max difference: 19.1
# Completed 34.5 % of episodes
# Max difference: 19.1
# Completed 34.599999999999994 % of episodes
# Max difference: 19.1
# Completed 34.699999999999996 % of episodes
# Max difference: 19.1
# Completed 34.8 % of episodes
# Max difference: 19.1
# Completed 34.9 % of episodes
# Max difference: 19.1
# Completed 35.0 % of episodes
# Max difference: 19.1
# Completed 35.099999999999994 % of episodes
# Max difference: 19.1
# Completed 35.199999999999996 % of episodes
# Max difference: 19.1
# Completed 35.3 % of episodes
# Max difference: 19.1
# Completed 35.4 % of episodes
# Max difference: 19.1
# Completed 35.5 % of episodes
# Max difference: 19.1
# Completed 35.6 % of episodes
# Max difference: 19.1
# Completed 35.699999999999996 % of episodes
# Max difference: 19.1
# Completed 35.8 % of episodes
# Max difference: 19.1
# Completed 35.9 % of episodes
# Max difference: 19.1
# Completed 36.0 % of episodes
# Max difference: 19.1
# Completed 36.1 % of episodes
# Max difference: 19.1
# Completed 36.199999999999996 % of episodes
# Max difference: 19.1
# Completed 36.3 % of episodes
# Max difference: 19.1
# Completed 36.4 % of episodes
# Max difference: 19.1
# Completed 36.5 % of episodes
# Max difference: 19.1
# Completed 36.6 % of episodes
# Max difference: 19.1
# Completed 36.7 % of episodes
# Max difference: 19.1
# Completed 36.8 % of episodes
# Max difference: 19.1
# Completed 36.9 % of episodes
# Max difference: 19.1
# Completed 37.0 % of episodes
# Max difference: 19.1
# Completed 37.1 % of episodes
# Max difference: 19.1
# Completed 37.2 % of episodes
# Max difference: 19.1
# Completed 37.3 % of episodes
# Max difference: 19.1
# Completed 37.4 % of episodes
# Max difference: 19.1
# Completed 37.5 % of episodes
# Max difference: 19.1
# Completed 37.6 % of episodes
# Max difference: 19.1
# Completed 37.7 % of episodes
# Max difference: 19.1
# Completed 37.8 % of episodes
# Max difference: 19.1
# Completed 37.9 % of episodes
# Max difference: 19.1
# Completed 38.0 % of episodes
# Max difference: 19.1
# Completed 38.1 % of episodes
# Max difference: 19.1
# Completed 38.2 % of episodes
# Max difference: 19.1
# Completed 38.3 % of episodes
# Max difference: 19.1
# Completed 38.4 % of episodes
# Max difference: 19.1
# Completed 38.5 % of episodes
# Max difference: 19.1
# Completed 38.6 % of episodes
# Max difference: 19.1
# Completed 38.7 % of episodes
# Max difference: 19.1
# Completed 38.800000000000004 % of episodes
# Max difference: 19.1
# Completed 38.9 % of episodes
# Max difference: 19.1
# Completed 39.0 % of episodes
# Max difference: 19.1
# Completed 39.1 % of episodes
# Max difference: 19.1
# Completed 39.2 % of episodes
# Max difference: 19.1
# Completed 39.300000000000004 % of episodes
# Max difference: 19.1
# Completed 39.4 % of episodes
# Max difference: 19.1
# Completed 39.5 % of episodes
# Max difference: 19.1
# Completed 39.6 % of episodes
# Max difference: 19.1
# Completed 39.7 % of episodes
# Max difference: 19.1
# Completed 39.800000000000004 % of episodes
# Max difference: 19.1
# Completed 39.900000000000006 % of episodes
# Max difference: 19.1
# Completed 40.0 % of episodes
# Max difference: 19.1
# Completed 40.1 % of episodes
# Max difference: 19.1
# Completed 40.2 % of episodes
# Max difference: 19.1
# Completed 40.300000000000004 % of episodes
# Max difference: 19.1
# Completed 40.400000000000006 % of episodes
# Max difference: 19.1
# Completed 40.5 % of episodes
# Max difference: 19.1
# Completed 40.6 % of episodes
# Max difference: 19.1
# Completed 40.699999999999996 % of episodes
# Max difference: 19.1
# Completed 40.8 % of episodes
# Max difference: 19.1
# Completed 40.9 % of episodes
# Max difference: 19.1
# Completed 41.0 % of episodes
# Max difference: 19.1
# Completed 41.099999999999994 % of episodes
# Max difference: 19.1
# Completed 41.199999999999996 % of episodes
# Max difference: 19.1
# Completed 41.3 % of episodes
# Max difference: 19.1
# Completed 41.4 % of episodes
# Max difference: 19.1
# Completed 41.5 % of episodes
# Max difference: 19.1
# Completed 41.6 % of episodes
# Max difference: 19.1
# Completed 41.699999999999996 % of episodes
# Max difference: 19.1
# Completed 41.8 % of episodes
# Max difference: 19.1
# Completed 41.9 % of episodes
# Max difference: 19.1
# Completed 42.0 % of episodes
# Max difference: 19.1
# Completed 42.1 % of episodes
# Max difference: 19.1
# Completed 42.199999999999996 % of episodes
# Max difference: 19.1
# Completed 42.3 % of episodes
# Max difference: 19.1
# Completed 42.4 % of episodes
# Max difference: 19.1
# Completed 42.5 % of episodes
# Max difference: 19.1
# Completed 42.6 % of episodes
# Max difference: 19.1
# Completed 42.699999999999996 % of episodes
# Max difference: 19.1
# Completed 42.8 % of episodes
# Max difference: 19.1
# Completed 42.9 % of episodes
# Max difference: 19.1
# Completed 43.0 % of episodes
# Max difference: 19.1
# Completed 43.1 % of episodes
# Max difference: 19.1
# Completed 43.2 % of episodes
# Max difference: 19.1
# Completed 43.3 % of episodes
# Max difference: 19.1
# Completed 43.4 % of episodes
# Max difference: 19.1
# Completed 43.5 % of episodes
# Max difference: 19.1
# Completed 43.6 % of episodes
# Max difference: 19.1
# Completed 43.7 % of episodes
# Max difference: 19.1
# Completed 43.8 % of episodes
# Max difference: 19.1
# Completed 43.9 % of episodes
# Max difference: 19.1
# Completed 44.0 % of episodes
# Max difference: 19.1
# Completed 44.1 % of episodes
# Max difference: 19.1
# Completed 44.2 % of episodes
# Max difference: 19.1
# Completed 44.3 % of episodes
# Max difference: 19.1
# Completed 44.4 % of episodes
# Max difference: 19.1
# Completed 44.5 % of episodes
# Max difference: 19.1
# Completed 44.6 % of episodes
# Max difference: 19.1
# Completed 44.7 % of episodes
# Max difference: 19.1
# Completed 44.800000000000004 % of episodes
# Max difference: 19.1
# Completed 44.9 % of episodes
# Max difference: 19.1
# Completed 45.0 % of episodes
# Max difference: 19.1
# Completed 45.1 % of episodes
# Max difference: 19.1
# Completed 45.2 % of episodes
# Max difference: 19.1
# Completed 45.300000000000004 % of episodes
# Max difference: 19.1
# Completed 45.4 % of episodes
# Max difference: 19.1
# Completed 45.5 % of episodes
# Max difference: 19.1
# Completed 45.6 % of episodes
# Max difference: 19.1
# Completed 45.7 % of episodes
# Max difference: 19.1
# Completed 45.800000000000004 % of episodes
# Max difference: 19.1
# Completed 45.9 % of episodes
# Max difference: 19.1
# Completed 46.0 % of episodes
# Max difference: 19.1
# Completed 46.1 % of episodes
# Max difference: 19.1
# Completed 46.2 % of episodes
# Max difference: 19.1
# Completed 46.300000000000004 % of episodes
# Max difference: 19.1
# Completed 46.400000000000006 % of episodes
# Max difference: 19.1
# Completed 46.5 % of episodes
# Max difference: 19.1
# Completed 46.6 % of episodes
# Max difference: 19.1
# Completed 46.7 % of episodes
# Max difference: 19.1
# Completed 46.800000000000004 % of episodes
# Max difference: 19.1
# Completed 46.9 % of episodes
# Max difference: 19.1
# Completed 47.0 % of episodes
# Max difference: 19.1
# Completed 47.099999999999994 % of episodes
# Max difference: 19.1
# Completed 47.199999999999996 % of episodes
# Max difference: 19.1
# Completed 47.3 % of episodes
# Max difference: 19.1
# Completed 47.4 % of episodes
# Max difference: 19.1
# Completed 47.5 % of episodes
# Max difference: 19.1
# Completed 47.599999999999994 % of episodes
# Max difference: 19.1
# Completed 47.699999999999996 % of episodes
# Max difference: 19.1
# Completed 47.8 % of episodes
# Max difference: 19.1
# Completed 47.9 % of episodes
# Max difference: 19.1
# Completed 48.0 % of episodes
# Max difference: 19.1
# Completed 48.1 % of episodes
# Max difference: 19.1
# Completed 48.199999999999996 % of episodes
# Max difference: 19.1
# Completed 48.3 % of episodes
# Max difference: 19.1
# Completed 48.4 % of episodes
# Max difference: 19.1
# Completed 48.5 % of episodes
# Max difference: 19.1
# Completed 48.6 % of episodes
# Max difference: 19.1
# Completed 48.699999999999996 % of episodes
# Max difference: 19.1
# Completed 48.8 % of episodes
# Max difference: 19.1
# Completed 48.9 % of episodes
# Max difference: 19.1
# Completed 49.0 % of episodes
# Max difference: 19.1
# Completed 49.1 % of episodes
# Max difference: 19.1
# Completed 49.2 % of episodes
# Max difference: 19.1
# Completed 49.3 % of episodes
# Max difference: 19.1
# Completed 49.4 % of episodes
# Max difference: 19.1
# Completed 49.5 % of episodes
# Max difference: 19.1
# Completed 49.6 % of episodes
# Max difference: 19.1
# Completed 49.7 % of episodes
# Max difference: 19.1
# Completed 49.8 % of episodes
# Max difference: 19.1
# Completed 49.9 % of episodes
# Max difference: 19.1
# Completed 50.0 % of episodes
# Max difference: 19.1
# Completed 50.1 % of episodes
# Max difference: 19.1
# Completed 50.2 % of episodes
# Max difference: 19.1
# Completed 50.3 % of episodes
# Max difference: 19.1
# Completed 50.4 % of episodes
# Max difference: 19.1
# Completed 50.5 % of episodes
# Max difference: 19.1
# Completed 50.6 % of episodes
# Max difference: 19.1
# Completed 50.7 % of episodes
# Max difference: 19.1
# Completed 50.8 % of episodes
# Max difference: 19.1
# Completed 50.9 % of episodes
# Max difference: 19.1
# Completed 51.0 % of episodes
# Max difference: 19.1
# Completed 51.1 % of episodes
# Max difference: 19.1
# Completed 51.2 % of episodes
# Max difference: 19.1
# Completed 51.300000000000004 % of episodes
# Max difference: 19.1
# Completed 51.4 % of episodes
# Max difference: 19.1
# Completed 51.5 % of episodes
# Max difference: 19.1
# Completed 51.6 % of episodes
# Max difference: 19.1
# Completed 51.7 % of episodes
# Max difference: 19.1
# Completed 51.800000000000004 % of episodes
# Max difference: 19.1
# Completed 51.9 % of episodes
# Max difference: 19.1
# Completed 52.0 % of episodes
# Max difference: 19.1
# Completed 52.1 % of episodes
# Max difference: 19.1
# Completed 52.2 % of episodes
# Max difference: 19.1
# Completed 52.300000000000004 % of episodes
# Max difference: 19.1
# Completed 52.400000000000006 % of episodes
# Max difference: 19.1
# Completed 52.5 % of episodes
# Max difference: 19.1
# Completed 52.6 % of episodes
# Max difference: 19.1
# Completed 52.7 % of episodes
# Max difference: 19.1
# Completed 52.800000000000004 % of episodes
# Max difference: 19.1
# Completed 52.900000000000006 % of episodes
# Max difference: 19.1
# Completed 53.0 % of episodes
# Max difference: 19.1
# Completed 53.1 % of episodes
# Max difference: 19.1
# Completed 53.2 % of episodes
# Max difference: 19.1
# Completed 53.300000000000004 % of episodes
# Max difference: 19.1
# Completed 53.400000000000006 % of episodes
# Max difference: 19.1
# Completed 53.5 % of episodes
# Max difference: 19.1
# Completed 53.6 % of episodes
# Max difference: 19.1
# Completed 53.7 % of episodes
# Max difference: 19.1
# Completed 53.800000000000004 % of episodes
# Max difference: 19.1
# Completed 53.900000000000006 % of episodes
# Max difference: 19.1
# Completed 54.0 % of episodes
# Max difference: 19.1
# Completed 54.1 % of episodes
# Max difference: 19.1
# Completed 54.2 % of episodes
# Max difference: 19.1
# Completed 54.300000000000004 % of episodes
# Max difference: 19.1
# Completed 54.400000000000006 % of episodes
# Max difference: 19.1
# Completed 54.50000000000001 % of episodes
# Max difference: 19.1
# Completed 54.6 % of episodes
# Max difference: 19.1
# Completed 54.7 % of episodes
# Max difference: 19.1
# Completed 54.800000000000004 % of episodes
# Max difference: 19.1
# Completed 54.900000000000006 % of episodes
# Max difference: 19.1
# Completed 55.00000000000001 % of episodes
# Max difference: 19.1
# Completed 55.1 % of episodes
# Max difference: 19.1
# Completed 55.2 % of episodes
# Max difference: 19.1
# Completed 55.300000000000004 % of episodes
# Max difference: 19.1
# Completed 55.400000000000006 % of episodes
# Max difference: 19.1
# Completed 55.50000000000001 % of episodes
# Max difference: 19.1
# Completed 55.60000000000001 % of episodes
# Max difference: 19.1
# Completed 55.7 % of episodes
# Max difference: 19.1
# Completed 55.800000000000004 % of episodes
# Max difference: 19.1
# Completed 55.900000000000006 % of episodes
# Max difference: 19.1
# Completed 56.00000000000001 % of episodes
# Max difference: 19.1
# Completed 56.10000000000001 % of episodes
# Max difference: 19.1
# Completed 56.2 % of episodes
# Max difference: 19.1
# Completed 56.3 % of episodes
# Max difference: 19.1
# Completed 56.39999999999999 % of episodes
# Max difference: 19.1
# Completed 56.49999999999999 % of episodes
# Max difference: 19.1
# Completed 56.599999999999994 % of episodes
# Max difference: 19.1
# Completed 56.699999999999996 % of episodes
# Max difference: 19.1
# Completed 56.8 % of episodes
# Max difference: 19.1
# Completed 56.89999999999999 % of episodes
# Max difference: 19.1
# Completed 56.99999999999999 % of episodes
# Max difference: 19.1
# Completed 57.099999999999994 % of episodes
# Max difference: 19.1
# Completed 57.199999999999996 % of episodes
# Max difference: 19.1
# Completed 57.3 % of episodes
# Max difference: 19.1
# Completed 57.4 % of episodes
# Max difference: 19.1
# Completed 57.49999999999999 % of episodes
# Max difference: 19.1
# Completed 57.599999999999994 % of episodes
# Max difference: 19.1
# Completed 57.699999999999996 % of episodes
# Max difference: 19.1
# Completed 57.8 % of episodes
# Max difference: 19.1
# Completed 57.9 % of episodes
# Max difference: 19.1
# Completed 57.99999999999999 % of episodes
# Max difference: 19.1
# Completed 58.099999999999994 % of episodes
# Max difference: 19.1
# Completed 58.199999999999996 % of episodes
# Max difference: 19.1
# Completed 58.3 % of episodes
# Max difference: 19.1
# Completed 58.4 % of episodes
# Max difference: 19.1
# Completed 58.5 % of episodes
# Max difference: 19.1
# Completed 58.599999999999994 % of episodes
# Max difference: 19.1
# Completed 58.699999999999996 % of episodes
# Max difference: 19.1
# Completed 58.8 % of episodes
# Max difference: 19.1
# Completed 58.9 % of episodes
# Max difference: 19.1
# Completed 59.0 % of episodes
# Max difference: 19.1
# Completed 59.099999999999994 % of episodes
# Max difference: 19.1
# Completed 59.199999999999996 % of episodes
# Max difference: 19.1
# Completed 59.3 % of episodes
# Max difference: 19.1
# Completed 59.4 % of episodes
# Max difference: 19.1
# Completed 59.5 % of episodes
# Max difference: 19.1
# Completed 59.599999999999994 % of episodes
# Max difference: 19.1
# Completed 59.699999999999996 % of episodes
# Max difference: 19.1
# Completed 59.8 % of episodes
# Max difference: 19.1
# Completed 59.9 % of episodes
# Max difference: 19.1
# Completed 60.0 % of episodes
# Max difference: 19.1
# Completed 60.099999999999994 % of episodes
# Max difference: 19.1
# Completed 60.199999999999996 % of episodes
# Max difference: 19.1
# Completed 60.3 % of episodes
# Max difference: 19.1
# Completed 60.4 % of episodes
# Max difference: 19.1
# Completed 60.5 % of episodes
# Max difference: 19.1
# Completed 60.6 % of episodes
# Max difference: 19.1
# Completed 60.699999999999996 % of episodes
# Max difference: 19.1
# Completed 60.8 % of episodes
# Max difference: 19.1
# Completed 60.9 % of episodes
# Max difference: 19.1
# Completed 61.0 % of episodes
# Max difference: 19.1
# Completed 61.1 % of episodes
# Max difference: 19.1
# Completed 61.199999999999996 % of episodes
# Max difference: 19.1
# Completed 61.3 % of episodes
# Max difference: 19.1
# Completed 61.4 % of episodes
# Max difference: 19.1
# Completed 61.5 % of episodes
# Max difference: 19.1
# Completed 61.6 % of episodes
# Max difference: 19.1
# Completed 61.7 % of episodes
# Max difference: 19.1
# Completed 61.8 % of episodes
# Max difference: 19.1
# Completed 61.9 % of episodes
# Max difference: 19.1
# Completed 62.0 % of episodes
# Max difference: 19.1
# Completed 62.1 % of episodes
# Max difference: 19.1
# Completed 62.2 % of episodes
# Max difference: 19.1
# Completed 62.3 % of episodes
# Max difference: 19.1
# Completed 62.4 % of episodes
# Max difference: 19.1
# Completed 62.5 % of episodes
# Max difference: 19.1
# Completed 62.6 % of episodes
# Max difference: 19.1
# Completed 62.7 % of episodes
# Max difference: 19.1
# Completed 62.8 % of episodes
# Max difference: 19.1
# Completed 62.9 % of episodes
# Max difference: 19.1
# Completed 63.0 % of episodes
# Max difference: 19.1
# Completed 63.1 % of episodes
# Max difference: 19.1
# Completed 63.2 % of episodes
# Max difference: 19.1
# Completed 63.3 % of episodes
# Max difference: 19.1
# Completed 63.4 % of episodes
# Max difference: 19.1
# Completed 63.5 % of episodes
# Max difference: 19.1
# Completed 63.6 % of episodes
# Max difference: 19.1
# Completed 63.7 % of episodes
# Max difference: 19.1
# Completed 63.800000000000004 % of episodes
# Max difference: 19.1
# Completed 63.9 % of episodes
# Max difference: 19.1
# Completed 64.0 % of episodes
# Max difference: 19.1
# Completed 64.1 % of episodes
# Max difference: 19.1
# Completed 64.2 % of episodes
# Max difference: 19.1
# Completed 64.3 % of episodes
# Max difference: 19.1
# Completed 64.4 % of episodes
# Max difference: 19.1
# Completed 64.5 % of episodes
# Max difference: 19.1
# Completed 64.60000000000001 % of episodes
# Max difference: 19.1
# Completed 64.7 % of episodes
# Max difference: 19.1
# Completed 64.8 % of episodes
# Max difference: 19.1
# Completed 64.9 % of episodes
# Max difference: 19.1
# Completed 65.0 % of episodes
# Max difference: 19.1
# Completed 65.10000000000001 % of episodes
# Max difference: 19.1
# Completed 65.2 % of episodes
# Max difference: 19.1
# Completed 65.3 % of episodes
# Max difference: 19.1
# Completed 65.4 % of episodes
# Max difference: 19.1
# Completed 65.5 % of episodes
# Max difference: 19.1
# Completed 65.60000000000001 % of episodes
# Max difference: 19.1
# Completed 65.7 % of episodes
# Max difference: 19.1
# Completed 65.8 % of episodes
# Max difference: 19.1
# Completed 65.9 % of episodes
# Max difference: 19.1
# Completed 66.0 % of episodes
# Max difference: 19.1
# Completed 66.10000000000001 % of episodes
# Max difference: 19.1
# Completed 66.2 % of episodes
# Max difference: 19.1
# Completed 66.3 % of episodes
# Max difference: 19.1
# Completed 66.4 % of episodes
# Max difference: 19.1
# Completed 66.5 % of episodes
# Max difference: 19.1
# Completed 66.60000000000001 % of episodes
# Max difference: 19.1
# Completed 66.7 % of episodes
# Max difference: 19.1
# Completed 66.8 % of episodes
# Max difference: 19.1
# Completed 66.9 % of episodes
# Max difference: 19.1
# Completed 67.0 % of episodes
# Max difference: 19.1
# Completed 67.10000000000001 % of episodes
# Max difference: 19.1
# Completed 67.2 % of episodes
# Max difference: 19.1
# Completed 67.30000000000001 % of episodes
# Max difference: 19.1
# Completed 67.4 % of episodes
# Max difference: 19.1
# Completed 67.5 % of episodes
# Max difference: 19.1
# Completed 67.60000000000001 % of episodes
# Max difference: 19.1
# Completed 67.7 % of episodes
# Max difference: 19.1
# Completed 67.80000000000001 % of episodes
# Max difference: 19.1
# Completed 67.9 % of episodes
# Max difference: 19.1
# Completed 68.0 % of episodes
# Max difference: 19.1
# Completed 68.10000000000001 % of episodes
# Max difference: 19.1
# Completed 68.2 % of episodes
# Max difference: 19.1
# Completed 68.30000000000001 % of episodes
# Max difference: 19.1
# Completed 68.4 % of episodes
# Max difference: 19.1
# Completed 68.5 % of episodes
# Max difference: 19.1
# Completed 68.60000000000001 % of episodes
# Max difference: 19.1
# Completed 68.7 % of episodes
# Max difference: 19.1
# Completed 68.8 % of episodes
# Max difference: 19.1
# Completed 68.89999999999999 % of episodes
# Max difference: 19.1
# Completed 69.0 % of episodes
# Max difference: 19.1
# Completed 69.1 % of episodes
# Max difference: 19.1
# Completed 69.19999999999999 % of episodes
# Max difference: 19.1
# Completed 69.3 % of episodes
# Max difference: 19.1
# Completed 69.39999999999999 % of episodes
# Max difference: 19.1
# Completed 69.5 % of episodes
# Max difference: 19.1
# Completed 69.6 % of episodes
# Max difference: 19.1
# Completed 69.69999999999999 % of episodes
# Max difference: 19.1
# Completed 69.8 % of episodes
# Max difference: 19.1
# Completed 69.89999999999999 % of episodes
# Max difference: 19.1
# Completed 70.0 % of episodes
# Max difference: 19.1
# Completed 70.1 % of episodes
# Max difference: 19.1
# Completed 70.19999999999999 % of episodes
# Max difference: 19.1
# Completed 70.3 % of episodes
# Max difference: 19.1
# Completed 70.39999999999999 % of episodes
# Max difference: 19.1
# Completed 70.5 % of episodes
# Max difference: 19.1
# Completed 70.6 % of episodes
# Max difference: 19.1
# Completed 70.7 % of episodes
# Max difference: 19.1
# Completed 70.8 % of episodes
# Max difference: 19.1
# Completed 70.89999999999999 % of episodes
# Max difference: 19.1
# Completed 71.0 % of episodes
# Max difference: 19.1
# Completed 71.1 % of episodes
# Max difference: 19.1
# Completed 71.2 % of episodes
# Max difference: 19.1
# Completed 71.3 % of episodes
# Max difference: 19.1
# Completed 71.39999999999999 % of episodes
# Max difference: 19.1
# Completed 71.5 % of episodes
# Max difference: 19.1
# Completed 71.6 % of episodes
# Max difference: 19.1
# Completed 71.7 % of episodes
# Max difference: 19.1
# Completed 71.8 % of episodes
# Max difference: 19.1
# Completed 71.89999999999999 % of episodes
# Max difference: 19.1
# Completed 72.0 % of episodes
# Max difference: 19.1
# Completed 72.1 % of episodes
# Max difference: 19.1
# Completed 72.2 % of episodes
# Max difference: 19.1
# Completed 72.3 % of episodes
# Max difference: 19.1
# Completed 72.39999999999999 % of episodes
# Max difference: 19.1
# Completed 72.5 % of episodes
# Max difference: 19.1
# Completed 72.6 % of episodes
# Max difference: 19.1
# Completed 72.7 % of episodes
# Max difference: 19.1
# Completed 72.8 % of episodes
# Max difference: 19.1
# Completed 72.89999999999999 % of episodes
# Max difference: 19.1
# Completed 73.0 % of episodes
# Max difference: 19.1
# Completed 73.1 % of episodes
# Max difference: 19.1
# Completed 73.2 % of episodes
# Max difference: 19.1
# Completed 73.3 % of episodes
# Max difference: 19.1
# Completed 73.4 % of episodes
# Max difference: 19.1
# Completed 73.5 % of episodes
# Max difference: 19.1
# Completed 73.6 % of episodes
# Max difference: 19.1
# Completed 73.7 % of episodes
# Max difference: 19.1
# Completed 73.8 % of episodes
# Max difference: 19.1
# Completed 73.9 % of episodes
# Max difference: 19.1
# Completed 74.0 % of episodes
# Max difference: 19.1
# Completed 74.1 % of episodes
# Max difference: 19.1
# Completed 74.2 % of episodes
# Max difference: 19.1
# Completed 74.3 % of episodes
# Max difference: 19.1
# Completed 74.4 % of episodes
# Max difference: 19.1
# Completed 74.5 % of episodes
# Max difference: 19.1
# Completed 74.6 % of episodes
# Max difference: 19.1
# Completed 74.7 % of episodes
# Max difference: 19.1
# Completed 74.8 % of episodes
# Max difference: 19.1
# Completed 74.9 % of episodes
# Max difference: 19.1
# Completed 75.0 % of episodes
# Max difference: 19.1
# Completed 75.1 % of episodes
# Max difference: 19.1
# Completed 75.2 % of episodes
# Max difference: 19.1
# Completed 75.3 % of episodes
# Max difference: 19.1
# Completed 75.4 % of episodes
# Max difference: 19.1
# Completed 75.5 % of episodes
# Max difference: 19.1
# Completed 75.6 % of episodes
# Max difference: 19.1
# Completed 75.7 % of episodes
# Max difference: 19.1
# Completed 75.8 % of episodes
# Max difference: 19.1
# Completed 75.9 % of episodes
# Max difference: 19.1
# Completed 76.0 % of episodes
# Max difference: 19.1
# Completed 76.1 % of episodes
# Max difference: 19.1
# Completed 76.2 % of episodes
# Max difference: 19.1
# Completed 76.3 % of episodes
# Max difference: 19.1
# Completed 76.4 % of episodes
# Max difference: 19.1
# Completed 76.5 % of episodes
# Max difference: 19.1
# Completed 76.6 % of episodes
# Max difference: 19.1
# Completed 76.7 % of episodes
# Max difference: 19.1
# Completed 76.8 % of episodes
# Max difference: 19.1
# Completed 76.9 % of episodes
# Max difference: 19.1
# Completed 77.0 % of episodes
# Max difference: 19.1
# Completed 77.10000000000001 % of episodes
# Max difference: 19.1
# Completed 77.2 % of episodes
# Max difference: 19.1
# Completed 77.3 % of episodes
# Max difference: 19.1
# Completed 77.4 % of episodes
# Max difference: 19.1
# Completed 77.5 % of episodes
# Max difference: 19.1
# Completed 77.60000000000001 % of episodes
# Max difference: 19.1
# Completed 77.7 % of episodes
# Max difference: 19.1
# Completed 77.8 % of episodes
# Max difference: 19.1
# Completed 77.9 % of episodes
# Max difference: 19.1
# Completed 78.0 % of episodes
# Max difference: 19.1
# Completed 78.10000000000001 % of episodes
# Max difference: 19.1
# Completed 78.2 % of episodes
# Max difference: 19.1
# Completed 78.3 % of episodes
# Max difference: 19.1
# Completed 78.4 % of episodes
# Max difference: 19.1
# Completed 78.5 % of episodes
# Max difference: 19.1
# Completed 78.60000000000001 % of episodes
# Max difference: 19.1
# Completed 78.7 % of episodes
# Max difference: 19.1
# Completed 78.8 % of episodes
# Max difference: 19.1
# Completed 78.9 % of episodes
# Max difference: 19.1
# Completed 79.0 % of episodes
# Max difference: 19.1
# Completed 79.10000000000001 % of episodes
# Max difference: 19.1
# Completed 79.2 % of episodes
# Max difference: 19.1
# Completed 79.3 % of episodes
# Max difference: 19.1
# Completed 79.4 % of episodes
# Max difference: 19.1
# Completed 79.5 % of episodes
# Max difference: 19.1
# Completed 79.60000000000001 % of episodes
# Max difference: 19.1
# Completed 79.7 % of episodes
# Max difference: 19.1
# Completed 79.80000000000001 % of episodes
# Max difference: 19.1
# Completed 79.9 % of episodes
# Max difference: 19.1
# Completed 80.0 % of episodes
# Max difference: 19.1
# Completed 80.10000000000001 % of episodes
# Max difference: 19.1
# Completed 80.2 % of episodes
# Max difference: 19.1
# Completed 80.30000000000001 % of episodes
# Max difference: 19.1
# Completed 80.4 % of episodes
# Max difference: 19.1
# Completed 80.5 % of episodes
# Max difference: 19.1
# Completed 80.60000000000001 % of episodes
# Max difference: 19.1
# Completed 80.7 % of episodes
# Max difference: 19.1
# Completed 80.80000000000001 % of episodes
# Max difference: 19.1
# Completed 80.9 % of episodes
# Max difference: 19.1
# Completed 81.0 % of episodes
# Max difference: 19.1
# Completed 81.10000000000001 % of episodes
# Max difference: 19.1
# Completed 81.2 % of episodes
# Max difference: 19.1
# Completed 81.3 % of episodes
# Max difference: 19.1
# Completed 81.39999999999999 % of episodes
# Max difference: 19.1
# Completed 81.5 % of episodes
# Max difference: 19.1
# Completed 81.6 % of episodes
# Max difference: 19.1
# Completed 81.69999999999999 % of episodes
# Max difference: 19.1
# Completed 81.8 % of episodes
# Max difference: 19.1
# Completed 81.89999999999999 % of episodes
# Max difference: 19.1
# Completed 82.0 % of episodes
# Max difference: 19.1
# Completed 82.1 % of episodes
# Max difference: 19.1
# Completed 82.19999999999999 % of episodes
# Max difference: 19.1
# Completed 82.3 % of episodes
# Max difference: 19.1
# Completed 82.39999999999999 % of episodes
# Max difference: 19.1
# Completed 82.5 % of episodes
# Max difference: 19.1
# Completed 82.6 % of episodes
# Max difference: 19.1
# Completed 82.69999999999999 % of episodes
# Max difference: 19.1
# Completed 82.8 % of episodes
# Max difference: 19.1
# Completed 82.89999999999999 % of episodes
# Max difference: 19.1
# Completed 83.0 % of episodes
# Max difference: 19.1
# Completed 83.1 % of episodes
# Max difference: 19.1
# Completed 83.2 % of episodes
# Max difference: 19.1
# Completed 83.3 % of episodes
# Max difference: 19.1
# Completed 83.39999999999999 % of episodes
# Max difference: 19.1
# Completed 83.5 % of episodes
# Max difference: 19.1
# Completed 83.6 % of episodes
# Max difference: 19.1
# Completed 83.7 % of episodes
# Max difference: 19.1
# Completed 83.8 % of episodes
# Max difference: 19.1
# Completed 83.89999999999999 % of episodes
# Max difference: 19.1
# Completed 84.0 % of episodes
# Max difference: 19.1
# Completed 84.1 % of episodes
# Max difference: 19.1
# Completed 84.2 % of episodes
# Max difference: 19.1
# Completed 84.3 % of episodes
# Max difference: 19.1
# Completed 84.39999999999999 % of episodes
# Max difference: 19.1
# Completed 84.5 % of episodes
# Max difference: 19.1
# Completed 84.6 % of episodes
# Max difference: 19.1
# Completed 84.7 % of episodes
# Max difference: 19.1
# Completed 84.8 % of episodes
# Max difference: 19.1
# Completed 84.89999999999999 % of episodes
# Max difference: 19.1
# Completed 85.0 % of episodes
# Max difference: 19.1
# Completed 85.1 % of episodes
# Max difference: 19.1
# Completed 85.2 % of episodes
# Max difference: 19.1
# Completed 85.3 % of episodes
# Max difference: 19.1
# Completed 85.39999999999999 % of episodes
# Max difference: 19.1
# Completed 85.5 % of episodes
# Max difference: 19.1
# Completed 85.6 % of episodes
# Max difference: 19.1
# Completed 85.7 % of episodes
# Max difference: 19.1
# Completed 85.8 % of episodes
# Max difference: 19.1
# Completed 85.9 % of episodes
# Max difference: 19.1
# Completed 86.0 % of episodes
# Max difference: 19.1
# Completed 86.1 % of episodes
# Max difference: 19.1
# Completed 86.2 % of episodes
# Max difference: 19.1
# Completed 86.3 % of episodes
# Max difference: 19.1
# Completed 86.4 % of episodes
# Max difference: 19.1
# Completed 86.5 % of episodes
# Max difference: 19.1
# Completed 86.6 % of episodes
# Max difference: 19.1
# Completed 86.7 % of episodes
# Max difference: 19.1
# Completed 86.8 % of episodes
# Max difference: 19.1
# Completed 86.9 % of episodes
# Max difference: 19.1
# Completed 87.0 % of episodes
# Max difference: 19.1
# Completed 87.1 % of episodes
# Max difference: 19.1
# Completed 87.2 % of episodes
# Max difference: 19.1
# Completed 87.3 % of episodes
# Max difference: 19.1
# Completed 87.4 % of episodes
# Max difference: 19.1
# Completed 87.5 % of episodes
# Max difference: 19.1
# Completed 87.6 % of episodes
# Max difference: 19.1
# Completed 87.7 % of episodes
# Max difference: 19.1
# Completed 87.8 % of episodes
# Max difference: 19.1
# Completed 87.9 % of episodes
# Max difference: 19.1
# Completed 88.0 % of episodes
# Max difference: 19.1
# Completed 88.1 % of episodes
# Max difference: 19.1
# Completed 88.2 % of episodes
# Max difference: 19.1
# Completed 88.3 % of episodes
# Max difference: 19.1
# Completed 88.4 % of episodes
# Max difference: 19.1
# Completed 88.5 % of episodes
# Max difference: 19.1
# Completed 88.6 % of episodes
# Max difference: 19.1
# Completed 88.7 % of episodes
# Max difference: 19.1
# Completed 88.8 % of episodes
# Max difference: 19.1
# Completed 88.9 % of episodes
# Max difference: 19.1
# Completed 89.0 % of episodes
# Max difference: 19.1
# Completed 89.1 % of episodes
# Max difference: 19.1
# Completed 89.2 % of episodes
# Max difference: 19.1
# Completed 89.3 % of episodes
# Max difference: 19.1
# Completed 89.4 % of episodes
# Max difference: 19.1
# Completed 89.5 % of episodes
# Max difference: 19.1
# Completed 89.60000000000001 % of episodes
# Max difference: 19.1
# Completed 89.7 % of episodes
# Max difference: 19.1
# Completed 89.8 % of episodes
# Max difference: 19.1
# Completed 89.9 % of episodes
# Max difference: 19.1
# Completed 90.0 % of episodes
# Max difference: 19.1
# Completed 90.10000000000001 % of episodes
# Max difference: 19.1
# Completed 90.2 % of episodes
# Max difference: 19.1
# Completed 90.3 % of episodes
# Max difference: 19.1
# Completed 90.4 % of episodes
# Max difference: 19.1
# Completed 90.5 % of episodes
# Max difference: 19.1
# Completed 90.60000000000001 % of episodes
# Max difference: 19.1
# Completed 90.7 % of episodes
# Max difference: 19.1
# Completed 90.8 % of episodes
# Max difference: 19.1
# Completed 90.9 % of episodes
# Max difference: 19.1
# Completed 91.0 % of episodes
# Max difference: 19.1
# Completed 91.10000000000001 % of episodes
# Max difference: 19.1
# Completed 91.2 % of episodes
# Max difference: 19.1
# Completed 91.3 % of episodes
# Max difference: 19.1
# Completed 91.4 % of episodes
# Max difference: 19.1
# Completed 91.5 % of episodes
# Max difference: 19.1
# Completed 91.60000000000001 % of episodes
# Max difference: 19.1
# Completed 91.7 % of episodes
# Max difference: 19.1
# Completed 91.8 % of episodes
# Max difference: 19.1
# Completed 91.9 % of episodes
# Max difference: 19.1
# Completed 92.0 % of episodes
# Max difference: 19.1
# Completed 92.10000000000001 % of episodes
# Max difference: 19.1
# Completed 92.2 % of episodes
# Max difference: 19.1
# Completed 92.30000000000001 % of episodes
# Max difference: 19.1
# Completed 92.4 % of episodes
# Max difference: 19.1
# Completed 92.5 % of episodes
# Max difference: 19.1
# Completed 92.60000000000001 % of episodes
# Max difference: 19.1
# Completed 92.7 % of episodes
# Max difference: 19.1
# Completed 92.80000000000001 % of episodes
# Max difference: 19.1
# Completed 92.9 % of episodes
# Max difference: 19.1
# Completed 93.0 % of episodes
# Max difference: 19.1
# Completed 93.10000000000001 % of episodes
# Max difference: 19.1
# Completed 93.2 % of episodes
# Max difference: 19.1
# Completed 93.30000000000001 % of episodes
# Max difference: 19.1
# Completed 93.4 % of episodes
# Max difference: 19.1
# Completed 93.5 % of episodes
# Max difference: 19.1
# Completed 93.60000000000001 % of episodes
# Max difference: 19.1
# Completed 93.7 % of episodes
# Max difference: 19.1
# Completed 93.8 % of episodes
# Max difference: 19.1
# Completed 93.89999999999999 % of episodes
# Max difference: 19.1
# Completed 94.0 % of episodes
# Max difference: 19.1
# Completed 94.1 % of episodes
# Max difference: 19.1
# Completed 94.19999999999999 % of episodes
# Max difference: 19.1
# Completed 94.3 % of episodes
# Max difference: 19.1
# Completed 94.39999999999999 % of episodes
# Max difference: 19.1
# Completed 94.5 % of episodes
# Max difference: 19.1
# Completed 94.6 % of episodes
# Max difference: 19.1
# Completed 94.69999999999999 % of episodes
# Max difference: 19.1
# Completed 94.8 % of episodes
# Max difference: 19.1
# Completed 94.89999999999999 % of episodes
# Max difference: 19.1
# Completed 95.0 % of episodes
# Max difference: 19.1
# Completed 95.1 % of episodes
# Max difference: 19.1
# Completed 95.19999999999999 % of episodes
# Max difference: 19.1
# Completed 95.3 % of episodes
# Max difference: 19.1
# Completed 95.39999999999999 % of episodes
# Max difference: 19.1
# Completed 95.5 % of episodes
# Max difference: 19.1
# Completed 95.6 % of episodes
# Max difference: 19.1
# Completed 95.7 % of episodes
# Max difference: 19.1
# Completed 95.8 % of episodes
# Max difference: 19.1
# Completed 95.89999999999999 % of episodes
# Max difference: 19.1
# Completed 96.0 % of episodes
# Max difference: 19.1
# Completed 96.1 % of episodes
# Max difference: 19.1
# Completed 96.2 % of episodes
# Max difference: 19.1
# Completed 96.3 % of episodes
# Max difference: 19.1
# Completed 96.39999999999999 % of episodes
# Max difference: 19.1
# Completed 96.5 % of episodes
# Max difference: 19.1
# Completed 96.6 % of episodes
# Max difference: 19.1
# Completed 96.7 % of episodes
# Max difference: 19.1
# Completed 96.8 % of episodes
# Max difference: 19.1
# Completed 96.89999999999999 % of episodes
# Max difference: 19.1
# Completed 97.0 % of episodes
# Max difference: 19.1
# Completed 97.1 % of episodes
# Max difference: 19.1
# Completed 97.2 % of episodes
# Max difference: 19.1
# Completed 97.3 % of episodes
# Max difference: 19.1
# Completed 97.39999999999999 % of episodes
# Max difference: 19.1
# Completed 97.5 % of episodes
# Max difference: 19.1
# Completed 97.6 % of episodes
# Max difference: 19.1
# Completed 97.7 % of episodes
# Max difference: 19.1
# Completed 97.8 % of episodes
# Max difference: 19.1
# Completed 97.89999999999999 % of episodes
# Max difference: 19.1
# Completed 98.0 % of episodes
# Max difference: 19.1
# Completed 98.1 % of episodes
# Max difference: 19.1
# Completed 98.2 % of episodes
# Max difference: 19.1
# Completed 98.3 % of episodes
# Max difference: 19.1
# Completed 98.4 % of episodes
# Max difference: 19.1
# Completed 98.5 % of episodes
# Max difference: 19.1
# Completed 98.6 % of episodes
# Max difference: 19.1
# Completed 98.7 % of episodes
# Max difference: 19.1
# Completed 98.8 % of episodes
# Max difference: 19.1
# Completed 98.9 % of episodes
# Max difference: 19.1
# Completed 99.0 % of episodes
# Max difference: 19.1
# Completed 99.1 % of episodes
# Max difference: 19.1
# Completed 99.2 % of episodes
# Max difference: 19.1
# Completed 99.3 % of episodes
# Max difference: 19.1
# Completed 99.4 % of episodes
# Max difference: 19.1
# Completed 99.5 % of episodes
# Max difference: 19.1
# Completed 99.6 % of episodes
# Max difference: 19.1
# Completed 99.7 % of episodes
# Max difference: 19.1
# Completed 99.8 % of episodes
# Max difference: 19.1
# Completed 99.9 % of episodes
# Max difference: 19.1
# Completed 100.0 % of episodes
# Max difference: 19.1
# done

# %%
observation, info = env.reset(seed=42)
done = False

while not done:
   action  = Policy[observation]
   observation, reward, terminated, truncated, info = env.step(action)

   if terminated or truncated:
      observation, info = env.reset()
   
   for event in pygame.event.get():
      if event.type == pygame.KEYDOWN:
         if event.key == pygame.K_ESCAPE:
            done = True

env.close()
